# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

# %%
from src.utils.setup_creds import get_bigquery_client

# %%
client = get_bigquery_client()

query = """
SELECT *
FROM `composed-task-345810.devinsight.scoped_events`
LIMIT 10;
"""

df = client.query(query).to_dataframe()
df.head()
# Out:
# /Users/pranavr/Desktop/Pranav/NEU /Spring26/Capstone/Proj_Code/.venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                  created_at  event_date  ... pr_merged review_state
# 0 2025-11-06 15:09:02+00:00  2025-11-06  ...      <NA>         None
# 1 2025-12-16 19:53:11+00:00  2025-12-16  ...      <NA>         None
# 2 2026-01-20 17:00:15+00:00  2026-01-20  ...      <NA>         None
# 3 2026-01-06 12:00:50+00:00  2026-01-06  ...      <NA>         None
# 4 2025-12-16 22:35:06+00:00  2025-12-16  ...      <NA>         None
#
# [5 rows x 9 columns]
